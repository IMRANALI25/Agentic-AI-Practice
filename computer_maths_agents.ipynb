# %% [markdown]
# <a href="https://colab.research.google.com/github/IMRANALI25/Agentic-AI-Practice/blob/main/computer_maths_agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🚀 Exploring the openai-agents Library with Gemini

# %% [markdown]
# #📦 installation

# %%
# !pip install -Uq openai-agents
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.5/168.5 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.2/160.2 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.0 MB/s eta 0:00:00

# %% [markdown]
# # 🔐 Imports Libraries if using Google Colab

# %%
from agents import Agent, Runner,OpenAIChatCompletionsModel, set_tracing_disabled
from openai import AsyncOpenAI

# %% [markdown]
# #📦 Imports

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# #🔐 Step 1: Setup for Api Keys

# %%
from google.colab import userdata
gemini_api_key = userdata.get("GEMINI_API_KEY")

# %% [markdown]
# # 🌐 Step 2: Client Setup for Connecting to Gemini
# ## 🔎 Tracing Disabled

# %%
set_tracing_disabled(disabled=True)

# %% [markdown]
# # ⚙️ Initialize LLM Service

# %%
client: AsyncOpenAI = AsyncOpenAI(
    api_key=gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
)

# %% [markdown]
# # 🎲 Initialize LLM Model

# %%
model: OpenAIChatCompletionsModel = OpenAIChatCompletionsModel(
    openai_client=client,
    model="gemini-2.5-flash",
)

# %% [markdown]
# # 🕵🏽 Create Agents

# %%
computer_agent: Agent = Agent(
    name="Computer Agent",
    instructions="""You are a helpful assistant
                              that can answer Computer Science questions.
                              You can help with programming, algorithms,
                              data structures, and more.
                              You can Generate Source Code/Programs
                              in Python, Javascript, C languages.""",
    model=model,
)

math_agent: Agent = Agent(
    name="Mathematics Agent",
    instructions="""You are a helpful Mathematics assistant
                    that can answer All Maths related questions.
                    You can help with Algebra, Geometry,
                    Calculus, and more.
                    You can Generate Source Code/Programs
                    in Python""",
    model=model,
)

# %% [markdown]
# # 🏃Running Agent Synchronously

# %%
def main():
    # Run the agent with a sample question
    result: Runner = Runner.run_sync(
        computer_agent,
        """ Create a generic program that randomly pick/use
            input integer number from range 1 - 1000.
            Then Create a computer program which outputs
            a MATH TABLE from the input number.
            The output table must  consists of 30 rows 1 - 30.
            The Source Program should be in Python,
            JavaScript and C Languages.
            The output should be in a well-formatted manner.""",
    )

    # Print the response
    print(result.final_output)

    result2: Runner = Runner.run_sync(
        math_agent,
        """ Create a generic program
    that can solve any mathematical problem including
    algebra, geometry, calculus, and more.
    The program should be able to take input from the user
    and provide a solution to the problem.
    The output should be in a well-formatted manner.""",
    )

    # Print the response
    print(result2.final_output)

# %% [markdown]
# # 💡Call main() method

# %%
if __name__ == "__main__":
    main()
# Out:
# Here are the programs in Python, JavaScript, and C, each designed to pick a random integer between 1 and 1000 and then output its multiplication table up to 30 rows.
#
# ---
#
# ### 1. Python Program
#
# This Python script utilizes the `random` module to generate a random number and then a simple `for` loop to print the multiplication table.
#
# ```python
# import random
#
# def generate_math_table_python():
#     """
#     Generates a random integer between 1 and 1000 and prints its
#     multiplication table up to 30 rows.
#     """
#     # Randomly pick an integer number from range 1 - 1000
#     random_number = random.randint(1, 1000)
#
#     print("-" * 40)
#     print(f"       MATH TABLE for {random_number}")
#     print("-" * 40)
#
#     # Generate and print the math table for 30 rows
#     for i in range(1, 31): # Loop from 1 to 30 (inclusive)
#         product = random_number * i
#         print(f"{random_number:4} x {i:2} = {product:6}") # Formatted output
#
#     print("-" * 40)
#
# # Call the function to execute the program
# if __name__ == "__main__":
#     generate_math_table_python()
# ```
#
# **How to Run (Python):**
# 1.  Save the code as `math_table.py`.
# 2.  Open a terminal or command prompt.
# 3.  Navigate to the directory where you saved the file.
# 4.  Run the command: `python math_table.py`
#
# **Sample Output (Python):**
#
# ```
# ----------------------------------------
#        MATH TABLE for 789
# ----------------------------------------
#  789 x  1 =    789
#  789 x  2 =   1578
#  789 x  3 =   2367
#  789 x  4 =   3156
#  789 x  5 =   3945
# ...
#  789 x 28 =  22092
#  789 x 29 =  22881
#  789 x 30 =  23670
# ----------------------------------------
# ```
#
# ---
#
# ### 2. JavaScript Program
#
# This JavaScript code can be run in a browser's console or using Node.js. It uses `Math.random()` to get the random number.
#
# ```javascript
# function generateMathTableJavaScript() {
#     /**
#      * Generates a random integer between 1 and 1000 and prints its
#      * multiplication table up to 30 rows.
#      */
#
#     // Randomly pick an integer number from range 1 - 1000
#     const randomNumber = Math.floor(Math.random() * 1000) + 1;
#
#     console.log("-".repeat(40));
#     console.log(`       MATH TABLE for ${randomNumber}`);
#     console.log("-".repeat(40));
#
#     // Generate and print the math table for 30 rows
#     for (let i = 1; i <= 30; i++) {
#         const product = randomNumber * i;
#         // Using template literals for formatted output
#         // Pad numbers to align columns using String.prototype.padStart
#         const numStr = String(randomNumber).padStart(4, ' ');
#         const iStr = String(i).padStart(2, ' ');
#         const productStr = String(product).padStart(6, ' ');
#         console.log(`${numStr} x ${iStr} = ${productStr}`);
#     }
#
#     console.log("-".repeat(40));
# }
#
# // Call the function to execute the program
# generateMathTableJavaScript();
# ```
#
# **How to Run (JavaScript):**
#
# *   **In a Browser:**
#     1.  Open your web browser's developer console (usually by pressing F12 or Ctrl+Shift+I).
#     2.  Go to the "Console" tab.
#     3.  Paste the entire code and press Enter.
# *   **Using Node.js:**
#     1.  Make sure you have Node.js installed.
#     2.  Save the code as `math_table.js`.
#     3.  Open a terminal or command prompt.
#     4.  Navigate to the directory where you saved the file.
#     5.  Run the command: `node math_table.js`
#
# **Sample Output (JavaScript - in console):**
#
# ```
# ----------------------------------------
#        MATH TABLE for 456
# ----------------------------------------
#  456 x  1 =    456
#  456 x  2 =    912
#  456 x  3 =   1368
#  456 x  4 =   1824
#  456 x  5 =   2280
# ...
#  456 x 28 =  12768
#  456 x 29 =  13224
#  456 x 30 =  13680
# ----------------------------------------
# ```
#
# ---
#
# ### 3. C Language Program
#
# The C program uses `rand()` and `srand(time(NULL))` for random number generation. It requires `<stdio.h>` for input/output and `<stdlib.h>` for `rand()`/`srand()`, and `<time.h>` for `time()`.
#
# ```c
# #include <stdio.h>  // Required for printf
# #include <stdlib.h> // Required for rand(), srand()
# #include <time.h>   // Required for time() to seed random number generator
#
# void generateMathTableC() {
#     /**
#      * Generates a random integer between 1 and 1000 and prints its
#      * multiplication table up to 30 rows.
#      */
#
#     // Seed the random number generator with current time
#     // This ensures different random numbers each time the program runs
#     srand(time(NULL));
#
#     // Randomly pick an integer number from range 1 - 1000
#     // rand() % 1000 gives a number from 0-999, adding 1 makes it 1-1000
#     int randomNumber = (rand() % 1000) + 1;
#
#     printf("----------------------------------------\n");
#     printf("       MATH TABLE for %d\n", randomNumber);
#     printf("----------------------------------------\n");
#
#     // Generate and print the math table for 30 rows
#     for (int i = 1; i <= 30; i++) {
#         int product = randomNumber * i;
#         // %4d for randomNumber to take 4 spaces (right-justified)
#         // %2d for i to take 2 spaces (right-justified)
#         // %6d for product to take 6 spaces (right-justified)
#         printf("%4d x %2d = %6d\n", randomNumber, i, product);
#     }
#
#     printf("----------------------------------------\n");
# }
#
# int main() {
#     // Call the function to execute the program
#     generateMathTableC();
#     return 0; // Indicate successful execution
# }
# ```
#
# **How to Compile and Run (C):**
# 1.  **Save:** Save the code as `math_table.c`.
# 2.  **Compile:** Open a terminal or command prompt and use a C compiler (like GCC):
#     `gcc math_table.c -o math_table`
# 3.  **Run:** Execute the compiled program:
#     *   On Windows: `.\math_table.exe`
#     *   On Linux/macOS: `./math_table`
#
# **Sample Output (C):**
#
# ```
# ----------------------------------------
#        MATH TABLE for 99
# ----------------------------------------
#   99 x  1 =     99
#   99 x  2 =    198
#   99 x  3 =    297
#   99 x  4 =    396
#   99 x  5 =    495
# ...
#   99 x 28 =   2772
#   99 x 29 =   2871
#   99 x 30 =   2970
# ----------------------------------------
# ```
# It's an exciting thought to create a truly "generic" program that can solve *any* mathematical problem. However, it's crucial to understand a fundamental limitation:
#
# **A single, truly generic program that can solve *any* mathematical problem (from basic arithmetic to complex topology proofs, from differential equations to abstract algebra group theory) is not realistically feasible with current technology.**
#
# Mathematics is an incredibly vast and diverse field, encompassing highly specialized domains, different modes of reasoning (symbolic, numerical, geometric, logical proof), and constantly evolving concepts.
#
# *   **Understanding the Problem:** A human mathematician first *understands* the problem's domain, context, and what's being asked. This requires a level of natural language understanding and mathematical intuition that is extremely challenging for a computer.
# *   **Choosing the Right Tool:** Even for a human, solving different math problems requires different tools and approaches (e.g., calculus for rates of change, linear algebra for systems of equations, proof techniques for abstract theorems).
# *   **Proof vs. Computation:** Many advanced mathematical problems involve constructing proofs, which is a creative and logical process far beyond mere computation.
#
# ---
#
# **What We *Can* Do in Python: A Powerful Symbolic & Numerical Solver**
#
# While a universal "solve all math" button is a dream, we *can* create a highly capable program that leverages powerful Python libraries to solve a *wide range* of symbolic and numerical problems commonly encountered in algebra, calculus, and basic geometry.
#
# The most suitable library for symbolic mathematics in Python is **SymPy**.
#
# **SymPy** allows you to:
# *   Define symbolic variables (like `x`, `y`).
# *   Perform algebraic manipulations (expand, simplify, factor).
# *   Solve equations (linear, quadratic, polynomial, transcendental).
# *   Perform calculus operations (derivatives, integrals, limits, series expansions).
# *   Work with matrices, vectors, and more.
#
# For numerical problems, **NumPy** and **SciPy** are indispensable, and for plotting, **Matplotlib**.
#
# ---
#
# **Program Design: A "Smart Assistant" Approach**
#
# My program will act as a *smart assistant* focusing on problems that can be expressed symbolically or numerically. It will:
# 1.  **Prompt the user** for the type of problem they want to solve.
# 2.  **Take specific input** based on the problem type (e.g., an equation string, an expression).
# 3.  **Use `sympy`** (or other libraries implicitly) to perform the necessary computations.
# 4.  **Display the result** in a clear, well-formatted way.
#
# ---
#
# **Python Program (Using SymPy)**
#
# This program will provide a menu-driven interface to perform common tasks in algebra and calculus.
#
# ```python
# import sympy
# from sympy import symbols, Eq, sympify, solve, diff, integrate, simplify, expand, series, limit
# from sympy.parsing.mathematica import parse_mathematica # For robustness in parsing
# import math # For numerical constant pi, etc.
#
#
# def get_expression_and_variable(prompt_expr="Enter the mathematical expression: ",
#                                 prompt_var="Enter the variable(s) (e.g., 'x', 'x y', 't'): "):
#     """Helper function to get expression string and define symbols."""
#     expr_str = input(prompt_expr)
#     var_str = input(prompt_var)
#
#     variables = []
#     for var_name in var_str.split():
#         variables.append(symbols(var_name))
#
#     # SymPy's sympify can convert string to SymPy expression.
#     # We pass a dictionary of local variables so it knows about our symbols.
#     try:
#         # Use a more robust parser if available, fallback to sympify
#         local_dict = {str(v): v for v in variables}
#         expr = sympify(expr_str, locals=local_dict)
#         return expr, variables
#     except (SyntaxError, TypeError, ValueError) as e:
#         print(f"Error parsing expression: {e}")
#         print("Please ensure valid Python syntax for mathematical operations (e.g., '**' for power, '*' for multiplication).")
#         return None, None
#
#
# def solve_equation():
#     print("\n--- Solve an Equation ---")
#     eq_str = input("Enter the equation to solve (e.g., 'x**2 - 4 = 0', '2*x + 5 = 10', 'sin(x) = 0'): ")
#     var_str = input("Enter the variable(s) to solve for (e.g., 'x', 'x y'): ")
#
#     variables = [symbols(v) for v in var_str.split()]
#
#     try:
#         # Check if it's an equality (e.g., 'lhs = rhs')
#         if '=' in eq_str:
#             lhs_str, rhs_str = eq_str.split('=', 1)
#             lhs = sympify(lhs_str, locals={str(v):v for v in variables})
#             rhs = sympify(rhs_str, locals={str(v):v for v in variables})
#             equation = Eq(lhs, rhs)
#         else:
#             # Assume it's an expression set to 0 if no '='
#             equation = sympify(eq_str, locals={str(v):v for v in variables})
#
#         if not variables:
#             print("Error: No variables specified to solve for.")
#             return
#
#         solutions = solve(equation, variables)
#
#         print(f"\nEquation: {equation}")
#         print(f"Solving for: {', '.join(str(v) for v in variables)}")
#         print("\n--- Solution(s) ---")
#         if solutions:
#             if isinstance(solutions, dict): # For multiple variables, returns dict
#                 for var, sol in solutions.items():
#                     print(f"{var} = {sol}")
#             else: # For single variable, returns list
#                 if len(solutions) == 0:
#                     print("No solutions found in the general domain.")
#                 else:
#                     for sol in solutions:
#                         print(f"{variables[0]} = {sol}")
#         else:
#             print("No solutions found or the equation is trivial/contradictory.")
#
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         print("Please check your equation format and variable declaration.")
#
#
# def differentiate_expression():
#     print("\n--- Differentiate an Expression ---")
#     expr, variables = get_expression_and_variable("Enter the expression to differentiate (e.g., 'x**3 + 2*x', 'sin(y)*x'): ",
#                                                 "Enter the variable with respect to which to differentiate (e.g., 'x'): ")
#     if expr is None: return
#
#     if not variables or len(variables) > 1:
#         print("Error: Please specify exactly one variable for differentiation.")
#         return
#
#     variable = variables[0]
#
#     try:
#         derivative = diff(expr, variable)
#         print(f"\nExpression: {expr}")
#         print(f"Differentiating with respect to: {variable}")
#         print("\n--- Result ---")
#         print(f"Derivative: {derivative}")
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         print("Please check your expression and variable.")
#
#
# def integrate_expression():
#     print("\n--- Integrate an Expression ---")
#     expr, variables = get_expression_and_variable("Enter the expression to integrate (e.g., 'x**2', '1/x'): ",
#                                                 "Enter the variable with respect to which to integrate (e.g., 'x'): ")
#     if expr is None: return
#
#     if not variables or len(variables) > 1:
#         print("Error: Please specify exactly one variable for integration.")
#         return
#
#     variable = variables[0]
#
#     try:
#         integral = integrate(expr, variable)
#         print(f"\nExpression: {expr}")
#         print(f"Integrating with respect to: {variable}")
#         print("\n--- Result ---")
#         print(f"Integral: {integral} + C (constant of integration)")
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         print("Please check your expression and variable.")
#         print("Note: SymPy may not be able to find a closed-form integral for all functions.")
#
#
# def simplify_expression():
#     print("\n--- Simplify an Expression ---")
#     expr_str = input("Enter the expression to simplify (e.g., '(x+y)**2 + x - x', 'sin(x)**2 + cos(x)**2'): ")
#     # Automatically define symbols found in the expression string
#     expr = sympify(expr_str)
#
#     print(f"\nOriginal Expression: {expr}")
#     try:
#         simplified_expr = simplify(expr)
#         print("\n--- Result ---")
#         print(f"Simplified: {simplified_expr}")
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         print("Please check your expression.")
#
#
# def expand_expression():
#     print("\n--- Expand an Expression ---")
#     expr_str = input("Enter the expression to expand (e.g., '(x+y)**2', '(a+b)*(a-b)'): ")
#     # Automatically define symbols found in the expression string
#     expr = sympify(expr_str)
#
#     print(f"\nOriginal Expression: {expr}")
#     try:
#         expanded_expr = expand(expr)
#         print("\n--- Result ---")
#         print(f"Expanded: {expanded_expr}")
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         print("Please check your expression.")
#
# def calculate_limit():
#     print("\n--- Calculate a Limit ---")
#     expr, variables = get_expression_and_variable("Enter the expression (e.g., 'sin(x)/x'): ",
#                                                   "Enter the variable for the limit (e.g., 'x'): ")
#     if expr is None: return
#
#     if not variables or len(variables) > 1:
#         print("Error: Please specify exactly one variable for the limit.")
#         return
#     variable = variables[0]
#
#     point_str = input(f"Enter the point 'a' as x approaches 'a' (e.g., '0', 'oo' for infinity, '-oo' for negative infinity): ")
#     try:
#         point = sympify(point_str, locals={'oo': sympy.oo, 'infinity': sympy.oo, 'pi': sympy.pi})
#     except Exception as e:
#         print(f"Error parsing limit point: {e}")
#         print("Ensure 'oo' is used for infinity.")
#         return
#
#     try:
#         limit_val = limit(expr, variable, point)
#         print(f"\nExpression: {expr}")
#         print(f"Variable: {variable}")
#         print(f"As {variable} approaches: {point}")
#         print("\n--- Result ---")
#         print(f"Limit: {limit_val}")
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         print("Please check your expression, variable, and limit point.")
#
# def main():
#     print("**************************************************")
#     print("*    Welcome to the Python Math Assistant!     *")
#     print("*  (Powered by SymPy for symbolic mathematics)   *")
#     print("**************************************************")
#     print("\nNote: This program handles common algebra and calculus problems.")
#     print("It cannot solve all types of mathematical problems (e.g., complex proofs, abstract theory).")
#     print("Use Python syntax for expressions (e.g., `**` for power, `*` for multiplication).")
#     print("For infinity, use 'oo'. For pi, use 'pi'.")
#
#     while True:
#         print("\nChoose a mathematical operation:")
#         print("1. Solve an Algebraic Equation")
#         print("2. Differentiate an Expression")
#         print("3. Integrate an Expression")
#         print("4. Simplify an Expression")
#         print("5. Expand an Expression")
#         print("6. Calculate a Limit")
#         print("7. Exit")
#
#         choice = input("Enter your choice (1-7): ")
#
#         if choice == '1':
#             solve_equation()
#         elif choice == '2':
#             differentiate_expression()
#         elif choice == '3':
#             integrate_expression()
#         elif choice == '4':
#             simplify_expression()
#         elif choice == '5':
#             expand_expression()
#         elif choice == '6':
#             calculate_limit()
#         elif choice == '7':
#             print("Thank you for using the Math Assistant. Goodbye!")
#             break
#         else:
#             print("Invalid choice. Please enter a number between 1 and 7.")
#
#         input("\nPress Enter to continue...") # Pause for user to read output
#
# if __name__ == "__main__":
#     main()
# ```
#
# ---
#
# **How to Run This Program:**
#
# 1.  **Install SymPy:** If you don't have it, open your terminal or command prompt and run:
#     ```bash
#     pip install sympy
#     ```
# 2.  **Save the Code:** Save the code above into a file named `math_solver.py` (or any `.py` name).
# 3.  **Run from Terminal:** Navigate to the directory where you saved the file and run:
#     ```bash
#     python math_solver.py
#     ```
#
# ---
#
# **Example Interactions:**
#
# ```
# **************************************************
# *    Welcome to the Python Math Assistant!     *
# *  (Powered by SymPy for symbolic mathematics)   *
# **************************************************
#
# Note: This program handles common algebra and calculus problems.
# It cannot solve all types of mathematical problems (e.g., complex proofs, abstract theory).
# Use Python syntax for expressions (e.g., `**` for power, `*` for multiplication).
# For infinity, use 'oo'. For pi, use 'pi'.
#
# Choose a mathematical operation:
# 1. Solve an Algebraic Equation
# 2. Differentiate an Expression
# 3. Integrate an Expression
# 4. Simplify an Expression
# 5. Expand an Expression
# 6. Calculate a Limit
# 7. Exit
# Enter your choice (1-7): 1
#
# --- Solve an Equation ---
# Enter the equation to solve (e.g., 'x**2 - 4 = 0', '2*x + 5 = 10', 'sin(x) = 0'): x**2 - 9 = 0
# Enter the variable(s) to solve for (e.g., 'x', 'x y'): x
#
# Equation: Eq(x**2 - 9, 0)
# Solving for: x
#
# --- Solution(s) ---
# x = -3
# x = 3
#
# Press Enter to continue...
#
# Choose a mathematical operation:
# 1. Solve an Algebraic Equation
# 2. Differentiate an Expression
# 3. Integrate an Expression
# 4. Simplify an Expression
# 5. Expand an Expression
# 6. Calculate a Limit
# 7. Exit
# Enter your choice (1-7): 2
#
# --- Differentiate an Expression ---
# Enter the expression to differentiate (e.g., 'x**3 + 2*x', 'sin(y)*x'): 3*x**2 + 5*x - 7
# Enter the variable with respect to which to differentiate (e.g., 'x'): x
#
# Expression: 3*x**2 + 5*x - 7
# Differentiating with respect to: x
#
# --- Result ---
# Derivative: 6*x + 5
#
# Press Enter to continue...
#
# Choose a mathematical operation:
# 1. Solve an Algebraic Equation
# 2. Differentiate an Expression
# 3. Integrate an Expression
# 4. Simplify an Expression
# 5. Expand an Expression
# 6. Calculate a Limit
# 7. Exit
# Enter your choice (1-7): 3
#
# --- Integrate an Expression ---
# Enter the expression to integrate (e.g., 'x**2', '1/x'): x**3
# Enter the variable with respect to which to integrate (e.g., 'x'): x
#
# Expression: x**3
# Integrating with respect to: x
#
# --- Result ---
# Integral: x**4/4 + C (constant of integration)
#
# Press Enter to continue...
#
# Choose a mathematical operation:
# 1. Solve an Algebraic Equation
# 2. Differentiate an Expression
# 3. Integrate an Expression
# 4. Simplify an Expression
# 5. Expand an Expression
# 6. Calculate a Limit
# 7. Exit
# Enter your choice (1-7): 6
#
# --- Calculate a Limit ---
# Enter the expression (e.g., 'sin(x)/x'): sin(x)/x
# Enter the variable for the limit (e.g., 'x'): x
# Enter the point 'a' as x approaches 'a' (e.g., '0', 'oo' for infinity, '-oo' for negative infinity): 0
#
# Expression: sin(x)/x
# Variable: x
# As x approaches: 0
#
# --- Result ---
# Limit: 1
#
# Press Enter to continue...
#
# Choose a mathematical operation:
# 1. Solve an Algebraic Equation
# 2. Differentiate an Expression
# 3. Integrate an Expression
# 4. Simplify an Expression
# 5. Expand an Expression
# 6. Calculate a Limit
# 7. Exit
# Enter your choice (1-7): 7
# Thank you for using the Math Assistant. Goodbye!
# ```
#
# ---
#
# **Further Enhancements (Beyond this Scope):**
#
# To make it more "generic" in a practical sense, one would need to:
#
# *   **Advanced Parsing:** Implement more sophisticated Natural Language Processing (NLP) to understand free-form mathematical questions ("What are the roots of x squared minus 5x plus 6?", "Find the area of a circle with radius 3"). This is a massive undertaking.
# *   **Geometry Module:** Integrate `sympy.geometry` for geometric calculations (area, perimeter, intersections of shapes).
# *   **Numerical Methods:** Incorporate `numpy` and `scipy` for numerical solutions to differential equations, optimization, linear algebra (for large matrices), statistical analysis, etc., which SymPy might not handle symbolically.
# *   **Plotting:** Use `matplotlib` to visualize functions, solutions, or data.
# *   **More Problem Types:** Expand to systems of equations, series, transforms (Laplace, Fourier), matrix operations, etc.
# *   **Interactive Sessions:** Allow users to define multiple variables and equations in a persistent session.
# *   **Equation Types:** Handle inequalities, absolute values, piecewise functions, etc., more robustly.
#
# Even with all these, the program would still be limited to computational and symbolic manipulation tasks, not creative mathematical proof generation or abstract theory interpretation.
